# %% [markdown]
# # EDA 2 - Working with the tags

# %%
# imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import seaborn as sns

# %%
# import cleaned dataframe

with open('data/df_cleaned.json', 'r') as f:
  data = json.load(f)

df = pd.DataFrame(data)

# check the data

df
# Out:
#                                              image_path  \
# 0     champkoi_data/18f755_A_32_Female_Kohaku_[Nogam...
# 1     gckoi_data/d9a7dbc_HIGH_QUALITY_SAKAI_BLOODLIN...
# 2     gckoi_data/88ec869_ISA_KOHAKU_GUARANTEE_FEMALE...
# 3     gckoi_data/3a7df4e_DAINICHI_3SAI_FEMALE_KOHAKU...
# 4     gckoi_data/cb26670_DAINICHI_BLOODLINE_KOHAKU_2...
# ...                                                 ...
# 3129  sacramentokoi_data/99a251_Yellow_Dragon_16″_–_...
# 3130  sacramentokoi_data/e04f2c_Yellow_Dragon_17″_–_...
# 3131  sacramentokoi_data/754a14_Yellow_Ginga_14″_–_2...
# 3132  sacramentokoi_data/1cb46d_Yellow_Ginga_19″_–_2...
# 3133  sacramentokoi_data/ba392c_Yellow_Ginga_20″_–_2...
#
#                                                    tags     uuid  length  \
# 0                                            ['Kohaku']   18f755    32.0
# 1                 ['kohaku', 'koi', 'Marukyu', 'nisai']  d9a7dbc    24.0
# 2                     ['isa', 'kohaku', 'koi', 'nisai']  88ec869    21.5
# 3     ['dainichi', 'fall 2024', 'kohaku', 'koi', 'sa...  3a7df4e    27.0
# 4     ['dainichi', 'fall 2024', 'kohaku', 'koi', 'ni...  cb26670    20.0
# ...                                                 ...      ...     ...
# 3129                           [Yellow, Dragon, Aokiya]   99a251    16.0
# 3130                           [Yellow, Dragon, Aokiya]   e04f2c    17.0
# 3131                                    [Yellow, Ginga]   754a14    14.0
# 3132                                    [Yellow, Ginga]   1cb46d    19.0
# 3133                                    [Yellow, Ginga]   ba392c    20.0
#
#       price_length  cleaned_price
# 0                7        14000.0
# 1                6         3500.0
# 2                6         2500.0
# 3                6         3800.0
# 4                5          600.0
# ...            ...            ...
# 3129             7          650.0
# 3130             7          600.0
# 3131             7          375.0
# 3132             9         1600.0
# 3133             9         2300.0
#
# [3134 rows x 6 columns]

# %%
# count all instances of all tags

tags_dict = {}

for tag_list in df['tags']:
  if isinstance(tag_list, list):
    for tag in tag_list:
      tags_dict[tag] = tags_dict.get(tag, 0) + 1

tags_dict
# Out:
# {'Gin': 274,
#  'Rin': 261,
#  'Showa': 179,
#  'showa': 1,
#  'Karashigoi': 15,
#  'Doitsu': 196,
#  'Kogane': 6,
#  'Ochiba': 46,
#  'Benigoi': 41,
#  'Ki': 28,
#  'Matsuba': 136,
#  'Hi': 54,
#  'Utsuri': 113,
#  'Tancho': 60,
#  'Sanke': 234,
#  'Goshiki': 37,
#  'Shiro': 51,
#  'Beni': 69,
#  'Kumonryu': 31,
#  'Maruten': 14,
#  'Hariwake': 304,
#  'Jumbo': 2,
#  'Kage': 2,
#  'Back': 1,
#  'Diamond': 4,
#  'Kohaku': 258,
#  'Kujaku': 301,
#  'Red': 2,
#  'Chagoi': 43,
#  'Asagi': 32,
#  'Platinum': 26,
#  'Kawarimono': 91,
#  'Black': 3,
#  'Matsukawabake': 6,
#  'Gi': 1,
#  'Saragoi': 1,
#  'Kin': 22,
#  'Cha': 1,
#  'Sumi': 3,
#  'Goromo': 44,
#  'Shusui': 68,
#  'Aka': 19,
#  'Yamabuki': 60,
#  'HI': 1,
#  'Kikokuryu': 86,
#  'Kigoi': 14,
#  'sanke': 2,
#  'rin': 1,
#  'Copper': 1,
#  'Kabuto': 1,
#  'Ginrin': 8,
#  'Mizuho': 2,
#  'Ogan': 2,
#  'Hutsuri': 1,
#  'Nijikawa': 1,
#  'Professional': 1,
#  '7MM': 1,
#  'Pellet-44': 1,
#  'lbs': 1,
#  'Aigoromo': 1,
#  'Yamato': 33,
#  'Nishiki': 37,
#  'Butterfly': 133,
#  'Penny"': 1,
#  'Nezu': 6,
#  'Ogon': 95,
#  'Soragoi': 23,
#  'Lemon': 2,
#  'Hikari': 3,
#  'Bekko': 80,
#  'Muji': 1,
#  'Kikusui': 97,
#  'Kinsui': 8,
#  'Root': 1,
#  'Beer': 1,
#  'Aragoke': 13,
#  'Orenji': 12,
#  'Tie"': 1,
#  'Shubunkin': 19,
#  'Goldfish': 10,
#  'Fancy': 2,
#  'Tail': 2,
#  'Top"': 1,
#  'Hesei': 1,
#  'RIn': 1,
#  'Kikisui': 1,
#  'Flower': 1,
#  'Heisei': 2,
#  'Metallic': 18,
#  'Karsugoi': 1,
#  'Cream': 1,
#  'Hisei': 1,
#  'Flannel"': 1,
#  'Toro': 2,
#  'Asagi and Shusui': 49,
#  'Imported Koi': 1582,
#  'Koi': 1582,
#  'Single Fish': 1871,
#  'Single Koi': 1582,
#  'Gosanke': 261,
#  'All Hikari Koi': 1017,
#  'Hikarimoyo': 842,
#  'Aka Bekko': 32,
#  'Shiro Bekko': 27,
#  'Fantail': 28,
#  'Goldfish For Sale': 289,
#  'Imported Goldfish': 289,
#  'Single Goldfish': 289,
#  '"Crystal\'s Featured Fish"': 280,
#  'Featured Goldfish': 48,
#  'Bubble Eye': 12,
#  'Ryukin': 48,
#  'Butterfly Koi': 795,
#  'Hikarimuji': 208,
#  'Yamato Nishiki': 85,
#  'Heisei Nishik': 29,
#  'Kin Kikokuryu': 77,
#  'Platinum Ogon': 39,
#  'Yamabuk': 15,
#  'Ochiba Shigure': 36,
#  'Heisei Nishiki': 44,
#  'Koromo': 28,
#  'Hi Utsuri': 28,
#  'Utsurimono': 44,
#  'Ki Utsuri': 7,
#  'Orenji Ogon': 32,
#  'Oranda': 103,
#  'Ki Bekko': 7,
#  'Gold Crown': 1,
#  'Shiro Utsuri': 9,
#  'Hajiro': 5,
#  'Butterfly Tail': 21,
#  'Other Tancho': 1,
#  'Wakin': 6,
#  'Beni Matsukawabakke': 3,
#  'Pearlscale': 19,
#  'Ranchu': 37,
#  'Matsukawabakke': 2,
#  'Sarasa Comet': 6,
#  '4-5" Koi & Butterfly Koi': 143,
#  'Ai': 4,
#  'Albino': 4,
#  'Mukashi': 6,
#  'Yellow': 15,
#  'Ginga': 8,
#  'Aokiya': 20,
#  'Kaneko': 3,
#  'Matsukawabaki': 2,
#  'Fukasawa': 2,
#  'Ikarashi': 8,
#  'Ozumi': 6,
#  'Karasu': 2,
#  'Toshi': 2,
#  'Pearl': 11,
#  'Scaled': 1,
#  'Zakura': 1,
#  'Sakura': 2,
#  'Dragon': 9}

# %%
# create a dictionary from the tags_dict

tags_df = pd.DataFrame(tags_dict.items(), columns=['tags', 'count'])

tags_df = tags_df.sort_values(by='count', ascending=False)
tags_df
# Out:
#                tags  count
# 97      Single Fish   1871
# 95     Imported Koi   1582
# 96              Koi   1582
# 98       Single Koi   1582
# 100  All Hikari Koi   1017
# ..              ...    ...
# 70             Muji      1
# 128      Gold Crown      1
# 73             Root      1
# 74             Beer      1
# 83            Hesei      1
#
# [158 rows x 2 columns]

# %%
# drop irrelevant tags

tags_df = tags_df[~tags_df['tags'].isin(['Single Fish', 'Imported Koi', 'Koi', 'Single Koi', 'Single Goldfish', 'Imported Goldfish',
                                         'Goldfish For Sale', '"Crystal\'s Featured Fish"', '4-5" Koi & Butterfly Koi'])]

# %%
# get the top 30

tags_df_30 = tags_df.sort_values(by='count', ascending=False).head(30)
tags_df_30
# Out:
#                tags  count
# 100  All Hikari Koi   1017
# 101      Hikarimoyo    842
# 112   Butterfly Koi    795
# 20         Hariwake    304
# 26           Kujaku    301
# 0               Gin    274
# 1               Rin    261
# 99          Gosanke    261
# 25           Kohaku    258
# 14            Sanke    234
# 113      Hikarimuji    208
# 5            Doitsu    196
# 2             Showa    179
# 10          Matsuba    136
# 62        Butterfly    133
# 12           Utsuri    113
# 126          Oranda    103
# 71          Kikusui     97
# 65             Ogon     95
# 31       Kawarimono     91
# 44        Kikokuryu     86
# 114  Yamato Nishiki     85
# 69            Bekko     80
# 116   Kin Kikokuryu     77
# 17             Beni     69
# 40           Shusui     68
# 13           Tancho     60
# 42         Yamabuki     60
# 11               Hi     54
# 16            Shiro     51

# %%
# export tags_df to csv

tags_df.to_csv('data/tags_df.csv', index=False)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=tags_df_30['tags'], y=tags_df_30['count'])
plt.title('Distribution of Tags Frequency', fontsize=20)
plt.xticks(rotation=90, fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.xlabel('Tag', fontsize=15)
plt.tight_layout()
plt.savefig('graphics/tags_frequency.png', transparent=True);

# %%
df[df['tags'].apply(lambda x: 'All Hikari Koi' in x)]
# Out:
#                                              image_path  \
# 843   nextdaykoi_data/62543bb1_3.5”_Imported_Armor_S...
# 845   nextdaykoi_data/f6ec77bc_3.5”_Imported_Gin_Rin...
# 846   nextdaykoi_data/0b5d40ad_3”_Imported_Gin_Rin_H...
# 848    nextdaykoi_data/5a01311a_3”_Imported_Kikusui.jpg
# 862   nextdaykoi_data/83c051ad_7”_Imported_Gin_Matsu...
# ...                                                 ...
# 2698  nextdaykoi_data/c816b4eb_7”_Imported_Kikusui_B...
# 2703  nextdaykoi_data/68edabd0_5.5”_Imported_Gin_Rin...
# 2704  nextdaykoi_data/934b39e8_5.5”_Imported_Kujaku.jpg
# 2707  nextdaykoi_data/fd039ce7_4.5”_Imported_Gin_Rin...
# 2708    nextdaykoi_data/d01a51dc_4”_Imported_Kujaku.jpg
#
#                                                    tags      uuid  length  \
# 843   [All Hikari Koi, Hariwake, Hikarimoyo, Importe...  62543bb1     3.5
# 845   [All Hikari Koi, Hariwake, Hikarimoyo, Importe...  f6ec77bc     3.5
# 846   [All Hikari Koi, Hariwake, Hikarimoyo, Importe...  0b5d40ad     3.0
# 848   [All Hikari Koi, Hikarimoyo, Imported Koi, Kik...  5a01311a     3.0
# 862   [All Hikari Koi, Butterfly Koi, Hikarimuji, Im...  83c051ad     7.0
# ...                                                 ...       ...     ...
# 2698  [All Hikari Koi, Butterfly Koi, Hikarimoyo, Im...  c816b4eb     7.0
# 2703  [All Hikari Koi, Hariwake, Hikarimoyo, Importe...  68edabd0     5.5
# 2704  [All Hikari Koi, Hikarimoyo, Imported Koi, Koi...  934b39e8     5.5
# 2707  [4-5" Koi & Butterfly Koi, All Hikari Koi, Har...  fd039ce7     4.5
# 2708  [4-5" Koi & Butterfly Koi, All Hikari Koi, Hik...  d01a51dc     4.0
#
#       price_length  cleaned_price
# 843              6           30.0
# 845              6           30.0
# 846              6           30.0
# 848              6           30.0
# 862              7          340.0
# ...            ...            ...
# 2698            14          136.0
# 2703            12           32.0
# 2704            12           32.0
# 2707            12           28.0
# 2708            12           28.0
#
# [1016 rows x 6 columns]

# %%
# check how many observations have 'Kohaku' in the tags

df[df['tags'].apply(lambda x: 'Kohaku' in x)]
# Out:
#                                              image_path  \
# 0     champkoi_data/18f755_A_32_Female_Kohaku_[Nogam...
# 62                     grandkoi_data/c424bc_Kohaku.jpeg
# 84                     grandkoi_data/f25237_Kohaku.jpeg
# 85                     grandkoi_data/cebd0a_Kohaku.jpeg
# 86                     grandkoi_data/54fe41_Kohaku.jpeg
# ...                                                 ...
# 2989  sacramentokoi_data/569caf_Kohaku_21″_–_2412972...
# 2990  sacramentokoi_data/d60117_Kohaku_25″_–_2406671...
# 3037  sacramentokoi_data/16a8f4_Pearl_Gin_Rin_Kohaku...
# 3107  sacramentokoi_data/bf71be_Tancho_Kohaku_16″_–_...
# 3108  sacramentokoi_data/5bacc3_Tancho_Kohaku_22″_–_...
#
#                            tags    uuid  length  price_length  cleaned_price
# 0                    ['Kohaku']  18f755    32.0             7        14000.0
# 62                     [Kohaku]  c424bc    28.0             9         9999.0
# 84                     [Kohaku]  f25237    29.0            10        15999.0
# 85                     [Kohaku]  cebd0a    31.0            10        20999.0
# 86                     [Kohaku]  54fe41    30.0            10        19999.0
# ...                         ...     ...     ...           ...            ...
# 2989                   [Kohaku]  569caf    21.0             9         3200.0
# 2990                   [Kohaku]  d60117    25.0             9         1800.0
# 3037  [Pearl, Gin, Rin, Kohaku]  16a8f4    17.0             7          575.0
# 3107           [Tancho, Kohaku]  bf71be    16.0             7          550.0
# 3108           [Tancho, Kohaku]  5bacc3    22.0             9         1800.0
#
# [259 rows x 6 columns]

# %%
# check how many observations have 'Sanke' in the tags

df[df['tags'].apply(lambda x: 'Sanke' in x)]
# Out:
#                                              image_path             tags  \
# 22               grandkoi_data/b1c670_Tancho Sanke.jpeg  [Tancho, Sanke]
# 23               grandkoi_data/58e2f4_Tancho Sanke.jpeg  [Tancho, Sanke]
# 59                     grandkoi_data/0a839c_Sanke-.jpeg          [Sanke]
# 157              grandkoi_data/474f2b_Tancho Sanke.jpeg  [Tancho, Sanke]
# 174                     grandkoi_data/040c9c_Sanke.jpeg          [Sanke]
# ...                                                 ...              ...
# 3057  sacramentokoi_data/e53be9_Sanke_19″_–_24036325...          [Sanke]
# 3058  sacramentokoi_data/b3d771_Sanke_19″_–_24066224...          [Sanke]
# 3059  sacramentokoi_data/5146b2_Sanke_20″_–_24036325...          [Sanke]
# 3060  sacramentokoi_data/3a20b7_Sanke_21″_–_24036325...          [Sanke]
# 3061  sacramentokoi_data/894274_Sanke_21″_–_24131024...          [Sanke]
#
#         uuid  length  price_length  cleaned_price
# 22    b1c670    22.0             9         3499.0
# 23    58e2f4    22.0             9         2999.0
# 59    0a839c    34.0            10        32999.0
# 157   474f2b    24.0             9         3499.0
# 174   040c9c    28.0             9         8999.0
# ...      ...     ...           ...            ...
# 3057  e53be9    19.0             7          850.0
# 3058  b3d771    19.0             9         1900.0
# 3059  5146b2    20.0             7          900.0
# 3060  3a20b7    21.0             9         1200.0
# 3061  894274    21.0             9         3200.0
#
# [234 rows x 6 columns]

# %%
# check how many observations have 'Showa' in the tags

df[df['tags'].apply(lambda x: 'Showa' in x)]
# Out:
#                                              image_path  \
# 13    grandkoi_data/12a49e_High Quality Gin Rin Show...
# 26              grandkoi_data/fa49a7_Gin Rin Showa.jpeg
# 27              grandkoi_data/3096cf_Gin Rin Showa.jpeg
# 31      grandkoi_data/f42319_Gin Rin Maruten Showa.jpeg
# 32              grandkoi_data/45d859_Gin Rin Showa.jpeg
# ...                                                 ...
# 3089  sacramentokoi_data/d32e7b_Showa_21″_–_24033524...
# 3090  sacramentokoi_data/705e77_Showa_21″_–_24033525...
# 3091  sacramentokoi_data/68c40e_Showa_21″_–_24107124...
# 3114  sacramentokoi_data/10e266_Tancho_Showa_15″_–_2...
# 3115  sacramentokoi_data/7cefa7_Tancho_Showa_17″_–_2...
#
#                             tags    uuid  length  price_length  cleaned_price
# 13             [Gin, Rin, Showa]  12a49e    32.0            10        34999.0
# 26             [Gin, Rin, Showa]  fa49a7    17.0             7          699.0
# 27             [Gin, Rin, Showa]  3096cf    17.0             9         1299.0
# 31    [Gin, Rin, Maruten, Showa]  f42319    24.0             9         3499.0
# 32             [Gin, Rin, Showa]  45d859    15.0             7          649.0
# ...                          ...     ...     ...           ...            ...
# 3089                     [Showa]  d32e7b    21.0             9         1600.0
# 3090                     [Showa]  705e77    21.0             9         1700.0
# 3091                     [Showa]  68c40e    21.0             9         2300.0
# 3114             [Tancho, Showa]  10e266    15.0             7          375.0
# 3115             [Tancho, Showa]  7cefa7    17.0             7          450.0
#
# [179 rows x 6 columns]

# %%
# see if there are any overlaps in Kohaku, Sanke and Showa, where a picture has more than 1 of these tags

print(df[df['tags'].apply(lambda x: 'Showa' in x)]['tags'].apply(lambda x: 'Sanke' in x).sum())
print(df[df['tags'].apply(lambda x: 'Showa' in x)]['tags'].apply(lambda x: 'Kohaku' in x).sum())
print(df[df['tags'].apply(lambda x: 'Sanke' in x)]['tags'].apply(lambda x: 'Kohaku' in x).sum())
# Out:
# 0
# 0
# 0

# %% [markdown]
# - there are no overlaps in tags, so they are mutually exclusive, so I can create separate train and test datasets without pictures being in multiple classes

# %%
# double check for duplicated images

df[['image_path']].duplicated().sum()
# Out:
# np.int64(0)

# %%
# tuples of image_path and labels, train-test-split those, create tensorflow dataset
