# %% [markdown]
# # EDA - Combining data from all 6 websites

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
# create a function to open files from json

def load_json(filename):
  with open(filename, 'r') as f:
    data = json.load(f)
  return pd.DataFrame(data)

# %%
# load all 6 dataframes

champkoi = load_json('champkoi.json')
gckoi = load_json('gckoi.json')
grandkoi = load_json('grandkoi.json')
kloubec = load_json('kloubec.json')
nextdaykoi = load_json('nextdaykoi.json')
sacramentokoi = load_json('sacramentokoi.json')

# %%
# create a function to put all the info from .info into a dataframe

def info_to_df(dataframe, abbreviation):
  # get the datatypes
  dtypes = dataframe.dtypes
  # get the non-null counts
  counts = dataframe.count()
  # create a new dataframe
  return pd.DataFrame({'Columns': dtypes.index, f'Non-Null_{abbreviation}': counts.values})

# %%
# create info dfs for all the dataframes

champkoi_info = info_to_df(champkoi, 'champkoi')
gckoi_info = info_to_df(gckoi, 'gckoi')
grandkoi_info = info_to_df(grandkoi, 'grandkoi')
kloubec_info = info_to_df(kloubec, 'kloubec')
nextdaykoi_info = info_to_df(nextdaykoi, 'nextdaykoi')
sacramentokoi_info = info_to_df(sacramentokoi, 'nextdaykoi')

# %%
# outer merge all the dataframes together

df = pd.merge(champkoi_info, gckoi_info, on='Columns', how='outer')
df = pd.merge(df, grandkoi_info, on='Columns', how='outer')
df = pd.merge(df, kloubec_info, on='Columns', how='outer')
df = pd.merge(df, nextdaykoi_info, on='Columns', how='outer')
df = pd.merge(df, sacramentokoi_info, on='Columns', how='outer')
df
# Out:
#                Columns  Non-Null_champkoi  Non-Null_gckoi  Non-Null_grandkoi  \
# 0                  age                NaN           402.0                NaN
# 1              breeder               35.0           402.0              361.0
# 2             category              185.0            30.0                NaN
# 3          certificate                NaN           402.0                NaN
# 4      cleaned_strings              185.0             NaN                NaN
# 5          description                NaN           402.0                NaN
# 6              details                NaN             NaN              367.0
# 7               gender               33.0           402.0                NaN
# 8             gpt_dict                NaN           408.0                NaN
# 9                image                NaN             NaN              367.0
# 10          image_path              185.0           408.0                NaN
# 11           image_url              185.0           408.0              367.0
# 12            in_stock              185.0           408.0                NaN
# 13           length_cm               35.0             NaN                NaN
# 14       length_inches               35.0           402.0              361.0
# 15                link              185.0           408.0              367.0
# 16       multiple_fish                NaN           402.0                NaN
# 17        out_of_stock                NaN             NaN                NaN
# 18               price              185.0           408.0              346.0
# 19                 sku              185.0           408.0              367.0
# 20               split              185.0             NaN                NaN
# 21                tags              185.0           408.0              367.0
# 22  tags_from_category                NaN             NaN                NaN
# 23     tags_from_title                NaN             NaN                NaN
# 24           tags_list              185.0             NaN                NaN
# 25               title              185.0           408.0              367.0
# 26                uuid              185.0           408.0              367.0
# 27             variety              185.0             NaN                NaN
#
#     Non-Null_kloubec  Non-Null_nextdaykoi_x  Non-Null_nextdaykoi_y
# 0                NaN                    NaN                    NaN
# 1                NaN                    NaN                    NaN
# 2                NaN                 1948.0                  423.0
# 3                NaN                    NaN                    NaN
# 4                NaN                    NaN                    NaN
# 5                NaN                    NaN                    NaN
# 6                NaN                    NaN                    NaN
# 7                NaN                  149.0                  156.0
# 8                NaN                    NaN                    NaN
# 9              517.0                 1948.0                  423.0
# 10               NaN                    NaN                    NaN
# 11             517.0                 1948.0                  423.0
# 12               NaN                    NaN                    NaN
# 13               NaN                    NaN                    NaN
# 14             517.0                 1903.0                  422.0
# 15             517.0                 1948.0                  423.0
# 16               NaN                    NaN                    NaN
# 17               NaN                    NaN                  423.0
# 18             517.0                 1948.0                  423.0
# 19             517.0                 1910.0                  422.0
# 20               NaN                    NaN                    NaN
# 21             517.0                 1948.0                  422.0
# 22               NaN                 1948.0                  423.0
# 23               NaN                 1948.0                  422.0
# 24               NaN                    NaN                    NaN
# 25             517.0                 1948.0                  423.0
# 26             517.0                 1948.0                  423.0
# 27               NaN                    NaN                    NaN

# %%
# change the index to 'Columns'

df = df.set_index('Columns')

# transpose the df

df.T
# Out:
# Columns                  age  breeder  category  certificate  cleaned_strings  \
# Non-Null_champkoi        NaN     35.0     185.0          NaN            185.0
# Non-Null_gckoi         402.0    402.0      30.0        402.0              NaN
# Non-Null_grandkoi        NaN    361.0       NaN          NaN              NaN
# Non-Null_kloubec         NaN      NaN       NaN          NaN              NaN
# Non-Null_nextdaykoi_x    NaN      NaN    1948.0          NaN              NaN
# Non-Null_nextdaykoi_y    NaN      NaN     423.0          NaN              NaN
#
# Columns                description  details  gender  gpt_dict   image  ...  \
# Non-Null_champkoi              NaN      NaN    33.0       NaN     NaN  ...
# Non-Null_gckoi               402.0      NaN   402.0     408.0     NaN  ...
# Non-Null_grandkoi              NaN    367.0     NaN       NaN   367.0  ...
# Non-Null_kloubec               NaN      NaN     NaN       NaN   517.0  ...
# Non-Null_nextdaykoi_x          NaN      NaN   149.0       NaN  1948.0  ...
# Non-Null_nextdaykoi_y          NaN      NaN   156.0       NaN   423.0  ...
#
# Columns                 price     sku  split    tags  tags_from_category  \
# Non-Null_champkoi       185.0   185.0  185.0   185.0                 NaN
# Non-Null_gckoi          408.0   408.0    NaN   408.0                 NaN
# Non-Null_grandkoi       346.0   367.0    NaN   367.0                 NaN
# Non-Null_kloubec        517.0   517.0    NaN   517.0                 NaN
# Non-Null_nextdaykoi_x  1948.0  1910.0    NaN  1948.0              1948.0
# Non-Null_nextdaykoi_y   423.0   422.0    NaN   422.0               423.0
#
# Columns                tags_from_title  tags_list   title    uuid  variety
# Non-Null_champkoi                  NaN      185.0   185.0   185.0    185.0
# Non-Null_gckoi                     NaN        NaN   408.0   408.0      NaN
# Non-Null_grandkoi                  NaN        NaN   367.0   367.0      NaN
# Non-Null_kloubec                   NaN        NaN   517.0   517.0      NaN
# Non-Null_nextdaykoi_x           1948.0        NaN  1948.0  1948.0      NaN
# Non-Null_nextdaykoi_y            422.0        NaN   423.0   423.0      NaN
#
# [6 rows x 28 columns]

# %%
# check the transposed df for nulls

df.T.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, Non-Null_champkoi to Non-Null_nextdaykoi_y
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 1 non-null      float64
#  1   breeder             3 non-null      float64
#  2   category            4 non-null      float64
#  3   certificate         1 non-null      float64
#  4   cleaned_strings     1 non-null      float64
#  5   description         1 non-null      float64
#  6   details             1 non-null      float64
#  7   gender              4 non-null      float64
#  8   gpt_dict            1 non-null      float64
#  9   image               4 non-null      float64
#  10  image_path          2 non-null      float64
#  11  image_url           6 non-null      float64
#  12  in_stock            2 non-null      float64
#  13  length_cm           1 non-null      float64
#  14  length_inches       6 non-null      float64
#  15  link                6 non-null      float64
#  16  multiple_fish       1 non-null      float64
#  17  out_of_stock        1 non-null      float64
#  18  price               6 non-null      float64
#  19  sku                 6 non-null      float64
#  20  split               1 non-null      float64
#  21  tags                6 non-null      float64
#  22  tags_from_category  2 non-null      float64
#  23  tags_from_title     2 non-null      float64
#  24  tags_list           1 non-null      float64
#  25  title               6 non-null      float64
#  26  uuid                6 non-null      float64
#  27  variety             1 non-null      float64
# dtypes: float64(28)
# memory usage: 1.5+ KB
