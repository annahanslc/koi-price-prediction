# %% [markdown]
# # Bigger Dataset - EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# import data

champkoi = pd.read_csv('../data/champkoi_data.csv')
gckoi = pd.read_csv('../data/gckoi_data.csv')
grandkoi = pd.read_csv('../data/grandkoi_data.csv')
kloubec = pd.read_csv('../data/kloubec_data.csv')
nextdaykoi = pd.read_csv('../data/nextdaykoi_data.csv')
sacramentokoi = pd.read_csv('../data/sacramentokoi_data.csv')

# %% [markdown]
# # Data from Champkoi - 185 pictures

# %%
# check the info

champkoi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   185 non-null    object
#  1   sku          185 non-null    int64
#  2   variety      185 non-null    object
#  3   title        185 non-null    object
#  4   price        185 non-null    float64
#  5   in_stock     185 non-null    bool
#  6   link         185 non-null    object
#  7   description  0 non-null      float64
#  8   category     185 non-null    object
#  9   tags         185 non-null    object
#  10  image_url    185 non-null    object
#  11  image_path   185 non-null    object
# dtypes: bool(1), float64(2), int64(1), object(8)
# memory usage: 16.2+ KB

# %%
# check the data

champkoi.head()
# Out:
#   Unnamed: 0            sku                               variety  \
# 0     87e22e  9689837273400      A: 14" (36cm) Female Showa [Isa]
# 1     188b5a  9689846350136        A: 14" (36cm) Male Showa [Isa]
# 2     911317  9689850118456        A: 13" (33cm) Male Showa [Isa]
# 3     dd27e7  9689853329720      A: 14" (36cm) Female Showa [Isa]
# 4     de2cb4  9689970475320  A: 14" (36cm) Male Kohaku [Marusaka]
#
#                                                title  price  in_stock  \
# 0  A: 14" (36cm) Female Showa [Isa] — 2025WINTER-012  450.0     False
# 1    A: 14" (36cm) Male Showa [Isa] — 2025WINTER-014  450.0      True
# 2    A: 13" (33cm) Male Showa [Isa] — 2025WINTER-015  450.0      True
# 3  A: 14" (36cm) Female Showa [Isa] — 2025WINTER-016  450.0     False
# 4  A: 14" (36cm) Male Kohaku [Marusaka] — 2025WIN...  450.0     False
#
#                                                link  description   category  \
# 0  https://www.champkoi.com/products/2025winter-012          NaN  Group_Koi
# 1  https://www.champkoi.com/products/2025winter-014          NaN  Group_Koi
# 2  https://www.champkoi.com/products/2025winter-015          NaN  Group_Koi
# 3  https://www.champkoi.com/products/2025winter-016          NaN  Group_Koi
# 4  https://www.champkoi.com/products/2025winter-017          NaN  Group_Koi
#
#                                    tags  \
# 0                             ['Showa']
# 1                             ['Showa']
# 2                             ['Showa']
# 3                             ['Showa']
# 4  ['Kohaku', 'Shiro Utsuri', 'Shusui']
#
#                                            image_url  \
# 0  https://cdn.shopify.com/s/files/1/0749/6132/22...
# 1  https://cdn.shopify.com/s/files/1/0749/6132/22...
# 2  https://cdn.shopify.com/s/files/1/0749/6132/22...
# 3  https://cdn.shopify.com/s/files/1/0749/6132/22...
# 4  https://cdn.shopify.com/s/files/1/0749/6132/22...
#
#                                           image_path
# 0  champkoi_data/87e22e_A_14_(36cm)_Female_Showa_...
# 1  champkoi_data/188b5a_A_14_(36cm)_Male_Showa_[I...
# 2  champkoi_data/911317_A_13_(33cm)_Male_Showa_[I...
# 3  champkoi_data/dd27e7_A_14_(36cm)_Female_Showa_...
# 4  champkoi_data/de2cb4_A_14_(36cm)_Male_Kohaku_[...

# %%
# split the title string to extract details

champkoi['split'] = champkoi['title'].apply(lambda x: x.split())

# %%
champkoi['split']
# Out:
# 0      [A:, 14", (36cm), Female, Showa, [Isa], —, 202...
# 1      [A:, 14", (36cm), Male, Showa, [Isa], —, 2025W...
# 2      [A:, 13", (33cm), Male, Showa, [Isa], —, 2025W...
# 3      [A:, 14", (36cm), Female, Showa, [Isa], —, 202...
# 4      [A:, 14", (36cm), Male, Kohaku, [Marusaka], —,...
#                              ...
# 180                 [Default, Title, —, 25D-024, Kujaku]
# 181     [Default, Title, —, 2024FALL-080, Mukashi, Ogon]
# 182          [Default, Title, —, 25D-031, Tancho, Showa]
# 183    [A:, 32", Female, Kohaku, [Nogami], —, 2023FAL...
# 184    [Default, Title, —, 2024FALL-127, Yellow, Muka...
# Name: split, Length: 185, dtype: object

# %%
# count the strings to see which terms are most frequently used, to help distinguish which varieties are in this dataset

counts = {}
for fish in champkoi['split']:
  for item in fish:
    counts[item] = counts.get(item, 0) + 1

# %%
# see the word count

df = pd.DataFrame(list(counts.items()), columns=['item', 'count'])
df = df.sort_values(by='count', ascending=False)
df.head(30)
# Out:
#            item  count
# 6             —    185
# 81      Default    150
# 82        Title    150
# 4         Showa     43
# 14       Kohaku     37
# 0            A:     35
# 44       Ginrin     25
# 3        Female     21
# 20       Golden     17
# 21         Corn     17
# 8          Male     12
# 131       Sanke     10
# 24       Doitsu      9
# 51       Kujaku      9
# 48          16"      8
# 27       (38cm)      8
# 26          15"      8
# 56       Tancho      8
# 49       (41cm)      8
# 29       Utsuri      6
# 2        (36cm)      6
# 1           14"      6
# 15   [Marusaka]      5
# 17         Beni      5
# 37          Kin      5
# 30   [Maruhiro]      5
# 43       (43cm)      4
# 57      Goshike      4
# 241        Ogon      4
# 42          17"      4

# %% [markdown]
# - remove dashes, 'Default', 'Title', 'A:' and anything that starts with a number, or open parenthesis
# - Showa, Kohaku, Bekko are all koi fish varieties
# - Extract additional features including: Female/Male
# - Extract trait information, such as: Golden, Ginrin, Doitsu
# - Get the fish length out as a separate feature, convert to either inches or cm to be consistent

# %% [markdown]
# # Data from GCKoi - 408 pictures

# %%
# check the info

gckoi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   408 non-null    object
#  1   sku          408 non-null    int64
#  2   title        408 non-null    object
#  3   price        408 non-null    float64
#  4   in_stock     408 non-null    bool
#  5   link         408 non-null    object
#  6   description  402 non-null    object
#  7   category     30 non-null     object
#  8   tags         408 non-null    object
#  9   image_url    408 non-null    object
#  10  image_path   408 non-null    object
# dtypes: bool(1), float64(1), int64(1), object(8)
# memory usage: 32.4+ KB

# %%
# check the data

gckoi.head()
# Out:
#   Unnamed: 0            sku  \
# 0    9718985  8428729860265
# 1    d9a7dbc  7856409346217
# 2    00d04b3  8291399860393
# 3    564bc0a  8305083449513
# 4    88ec869  7993174229161
#
#                                                title   price  in_stock  \
# 0                              GENJIRO GOSANKE 7"-9"    95.0      True
# 1  HIGH QUALITY SAKAI BLOODLINE TANCHO KOHAKU 24”...  3500.0      True
# 2     HIROI DOITSU SANKE-SHOWA-TANCHO OCHIBA 14"-16"   600.0     False
# 3                               IKARASHI MIX BOWL #1   600.0     False
# 4  ISA KOHAKU GUARANTEE FEMALE WITH CERTIFICATE 2...  2500.0      True
#
#                                                 link  \
# 0     https://gckoi.com/products/genjiro-gosanke-7-9
# 1  https://gckoi.com/products/high-quality-sakai-...
# 2  https://gckoi.com/products/hiroi-doitsu-sanke-...
# 3     https://gckoi.com/products/ikarashi-mix-bowl-1
# 4  https://gckoi.com/products/isa-showa-grow-out-...
#
#                                          description category  \
# 0  Breeder: Genjiro Kohaku, Sanke and ShowaSize: ...      NaN
# 1          Breeder: MarukyuSize: 3sai 24”Sex: female      NaN
# 2  *SHIP END OF NOVEMBER*Breeder: HiroiSex: 4 fem...      Koi
# 3  *SHIP END OF NOVEMBER*Breeder: IkarashiSex: 5 ...      NaN
# 4  Breeder: Isa with certificateSize: 21.5"Sex: f...      NaN
#
#                                                 tags  \
# 0  ['genjiro', 'kohaku', 'koi', 'sanke', 'showa',...
# 1              ['kohaku', 'koi', 'Marukyu', 'nisai']
# 2  ['fall 2024', 'HIROI', 'koi', 'nisai', 'ochiba...
# 3  ['Beni Kikokuryu', 'fall 2024', 'ikarashi', 'k...
# 4                  ['isa', 'kohaku', 'koi', 'nisai']
#
#                                            image_url  \
# 0  https://cdn.shopify.com/s/files/1/0565/8830/45...
# 1  https://cdn.shopify.com/s/files/1/0565/8830/45...
# 2  https://cdn.shopify.com/s/files/1/0565/8830/45...
# 3  https://cdn.shopify.com/s/files/1/0565/8830/45...
# 4  https://cdn.shopify.com/s/files/1/0565/8830/45...
#
#                                           image_path
# 0         gckoi_data/9718985_GENJIRO_GOSANKE_7-9.jpg
# 1  gckoi_data/d9a7dbc_HIGH_QUALITY_SAKAI_BLOODLIN...
# 2  gckoi_data/00d04b3_HIROI_DOITSU_SANKE-SHOWA-TA...
# 3        gckoi_data/564bc0a_IKARASHI_MIX_BOWL_#1.png
# 4  gckoi_data/88ec869_ISA_KOHAKU_GUARANTEE_FEMALE...

# %% [markdown]
# # Data from Grandkoi - 367 pictures

# %%
# check the info

grandkoi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  367 non-null    object
#  1   link        367 non-null    object
#  2   title       367 non-null    object
#  3   price       346 non-null    object
#  4   sku         367 non-null    object
#  5   details     367 non-null    object
#  6   image       367 non-null    object
#  7   image_url   367 non-null    object
# dtypes: object(8)
# memory usage: 23.1+ KB

# %%
# check the data

grandkoi.head()
# Out:
#   Unnamed: 0                                               link  \
# 0     d7c302  https://www.grandkoi.com/product/high-quality-...
# 1     12a49e  https://www.grandkoi.com/product/gin-rin-showa...
# 2     9ac3a8  https://www.grandkoi.com/product/high-quality-...
# 3     adf84d  https://www.grandkoi.com/product/karashigoi-8092/
# 4     a0b886  https://www.grandkoi.com/product/doitsu-kogane...
#
#                               title       price   sku  \
# 0          High Quality showa- SOLD         NaN  8098
# 1  High Quality Gin Rin Showa- SOLD  $34,999.00  8097
# 2  High Quality Gin Rin showa- SOLD  $34,999.00  8096
# 3                        Karashigoi  $32,999.00  8092
# 4        Doitsu Kogane Ochiba- SOLD  $24,999.00  8091
#
#                                  details  \
# 0  ['Breeder: Sakai<br>Inches: 30</br>']
# 1  ['Breeder: Sakai<br>Inches: 32</br>']
# 2  ['Breeder: Sakai<br>Inches: 32</br>']
# 3    ['Breeder: Dainichi', 'Inches: 36']
# 4     ['Breeder: Marusei', 'Inches: 31']
#
#                                                image  \
# 0  grandkoi_data/d7c302_High Quality showa- SOLD....
# 1  grandkoi_data/12a49e_High Quality Gin Rin Show...
# 2  grandkoi_data/9ac3a8_High Quality Gin Rin show...
# 3               grandkoi_data/adf84d_Karashigoi.jpeg
# 4  grandkoi_data/a0b886_Doitsu Kogane Ochiba- SOL...
#
#                                            image_url
# 0  https://www.grandkoi.com/wp-content/uploads/20...
# 1  https://www.grandkoi.com/wp-content/uploads/20...
# 2  https://www.grandkoi.com/wp-content/uploads/20...
# 3  https://www.grandkoi.com/wp-content/uploads/20...
# 4  https://www.grandkoi.com/wp-content/uploads/20...

# %% [markdown]
# # Data from Kloubec - 517 pictures

# %%
# check the info

kloubec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    517 non-null    object
#  1   link          517 non-null    object
#  2   title         517 non-null    object
#  3   description   516 non-null    object
#  4   category      517 non-null    object
#  5   out_of_stock  517 non-null    bool
#  6   price         517 non-null    float64
#  7   sku           517 non-null    int64
#  8   image         517 non-null    object
#  9   image_url     517 non-null    object
# dtypes: bool(1), float64(1), int64(1), object(7)
# memory usage: 37.0+ KB

# %%
# check the head

kloubec.head()
# Out:
#   Unnamed: 0                                               link  \
# 0     e66d83  https://www.kloubeckoi.com/10-12-showacase-sho...
# 1     7150be  https://www.kloubeckoi.com/14-doitsu-yamato-ni...
# 2     7ef4a6  https://www.kloubeckoi.com/11-kin-ki-utsuri-bu...
# 3     c52abb  https://www.kloubeckoi.com/13-chagoi-butterfly...
# 4     f54b07  https://www.kloubeckoi.com/12-skye-butterfly-k...
#
#                                          title  \
# 0     10-12" "Showacase" Showa Koi #K5430(X50)
# 1     14" Doitsu Yamato Nishiki Koi #K5429(P2)
# 2  11" Kin Ki Utsuri Butterfly Koi #K5427(X15)
# 3         13" Chagoi Butterfly Koi #K5426(X15)
# 4         12" "Skye" Butterfly Koi #K5425(X15)
#
#                                          description  \
# 0  Kloubec Koi Farm is your trusted source for th...
# 1  Kloubec Koi Farm is your trusted source for th...
# 2  Kloubec Koi Farm is your trusted source for th...
# 3  Kloubec Koi Farm is your trusted source for th...
# 4  Kloubec Koi Farm is your trusted source for th...
#
#                                             category  out_of_stock    price  \
# 0  ['Koi Fish For Sale', 'Koi Fish For Sale/Butte...         False  1599.99
# 1  ['Koi Fish For Sale', 'Koi Fish For Sale/Shop ...         False   299.99
# 2  ['Koi Fish For Sale', 'Koi Fish For Sale/Butte...         False   299.99
# 3  ['Koi Fish For Sale', 'Koi Fish For Sale/Butte...         False   299.99
# 4  ['Koi Fish For Sale', 'Koi Fish For Sale/Butte...         False   299.99
#
#      sku                                              image  \
# 0  22874  kloubec_data/e66d83_10-12_Showacase_Showa_Koi_...
# 1  22873  kloubec_data/7150be_14_Doitsu_Yamato_Nishiki_K...
# 2  22872  kloubec_data/7ef4a6_11_Kin_Ki_Utsuri_Butterfly...
# 3  22871  kloubec_data/c52abb_13_Chagoi_Butterfly_Koi_#K...
# 4  22870  kloubec_data/f54b07_12_Skye_Butterfly_Koi_#K54...
#
#                                            image_url
# 0  https://cdn11.bigcommerce.com/s-c81ee/images/s...
# 1  https://cdn11.bigcommerce.com/s-c81ee/images/s...
# 2  https://cdn11.bigcommerce.com/s-c81ee/images/s...
# 3  https://cdn11.bigcommerce.com/s-c81ee/images/s...
# 4  https://cdn11.bigcommerce.com/s-c81ee/images/s...

# %% [markdown]
# # Data from NextDayKoi - 1948 pictures

# %%
# check the info

nextdaykoi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1948 entries, 0 to 1947
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1948 non-null   object
#  1   link        1948 non-null   object
#  2   title       1948 non-null   object
#  3   category    1948 non-null   object
#  4   price       1948 non-null   object
#  5   sku         1910 non-null   object
#  6   image       1948 non-null   object
#  7   image_url   1948 non-null   object
# dtypes: object(8)
# memory usage: 121.9+ KB

# %%
# check the data

nextdaykoi.head()
# Out:
#   Unnamed: 0                                               link  \
# 0   02f31ccb  https://nextdaykoi.com/product/3-5-imported-sh...
# 1   bec4495e  https://nextdaykoi.com/product/3-5-imported-ko...
# 2   62543bb1  https://nextdaykoi.com/product/3-5-imported-ar...
# 3   ea7ff9e9  https://nextdaykoi.com/product/3-5-imported-be...
# 4   f6ec77bc  https://nextdaykoi.com/product/3-5-imported-gi...
#
#                                  title  \
# 0                 3.5” Imported Shusui
# 1                 3.5” Imported Kohaku
# 2  3.5” Imported Armor Scaled Hariwake
# 3       3.5” Imported Doitsu Aka Bekko
# 4       3.5” Imported Gin Rin Hariwake
#
#                                             category   price              sku  \
# 0  ['Asagi and Shusui', 'Imported Koi', 'Koi', 'S...  $30.00  HS0505G01515C14
# 1  ['Gosanke', 'Imported Koi', 'Kohaku', 'Koi', '...  $30.00  HS0505G01515C13
# 2  ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', '...  $30.00  HS0505G01515C11
# 3  ['Aka Bekko', 'Bekko', 'Imported Koi', 'Koi', ...  $30.00  HS0505G01515C10
# 4  ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', '...  $30.00  HS0505G01515C08
#
#                                                image  \
# 0  nextdaykoi_data/02f31ccb_3.5”_Imported_Shusui.jpg
# 1  nextdaykoi_data/bec4495e_3.5”_Imported_Kohaku.jpg
# 2  nextdaykoi_data/62543bb1_3.5”_Imported_Armor_S...
# 3  nextdaykoi_data/ea7ff9e9_3.5”_Imported_Doitsu_...
# 4  nextdaykoi_data/f6ec77bc_3.5”_Imported_Gin_Rin...
#
#                                            image_url
# 0  https://d2e07cbkdk0gwy.cloudfront.net/wp-conte...
# 1  https://d2e07cbkdk0gwy.cloudfront.net/wp-conte...
# 2  https://d2e07cbkdk0gwy.cloudfront.net/wp-conte...
# 3  https://d2e07cbkdk0gwy.cloudfront.net/wp-conte...
# 4  https://d2e07cbkdk0gwy.cloudfront.net/wp-conte...

# %% [markdown]
# # Data from Sacramentokoi - 423 pictures

# %%
# check the info

sacramentokoi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    423 non-null    object
#  1   link          423 non-null    object
#  2   title         423 non-null    object
#  3   category      423 non-null    object
#  4   out_of_stock  423 non-null    bool
#  5   price         423 non-null    object
#  6   sku           422 non-null    float64
#  7   image         423 non-null    object
#  8   image_url     423 non-null    object
# dtypes: bool(1), float64(1), object(7)
# memory usage: 27.0+ KB

# %%
# check the data

sacramentokoi.head()
# Out:
#   Unnamed: 0                                               link  \
# 0     cd3cf5  https://sacramentokoi.com/ai-goromo-10-240054222/
# 1     617c1b  https://sacramentokoi.com/ai-goromo-20-240389171/
# 2     5027b5  https://sacramentokoi.com/ai-goromo-23-240396257/
# 3     ebda82  https://sacramentokoi.com/ai-goromo-24-231616208/
# 4     10edc1  https://sacramentokoi.com/aka-matsuba-11-24005...
#
#                          title category  out_of_stock      price          sku  \
# 0    Ai Goromo 10″ – 240054222   Goromo          True    $150.00  240054222.0
# 1    Ai Goromo 20″ – 240389171   Female          True  $1,200.00  240389171.0
# 2    Ai Goromo 23″ – 240396257   Female          True  $1,200.00  240396257.0
# 3    Ai Goromo 27″ – 231616208   Female          True  $4,200.00  231616208.0
# 4  Aka Matsuba 11″ – 240054184      Koi          True    $175.00  240054184.0
#
#                                                image  \
# 0  sacramentokoi_data/cd3cf5_Ai_Goromo_10″_–_2400...
# 1  sacramentokoi_data/617c1b_Ai_Goromo_20″_–_2403...
# 2  sacramentokoi_data/5027b5_Ai_Goromo_23″_–_2403...
# 3  sacramentokoi_data/ebda82_Ai_Goromo_27″_–_2316...
# 4  sacramentokoi_data/10edc1_Aka_Matsuba_11″_–_24...
#
#                                            image_url
# 0  https://sacramentokoi.com/wp-content/uploads/2...
# 1  https://sacramentokoi.com/wp-content/uploads/2...
# 2  https://sacramentokoi.com/wp-content/uploads/2...
# 3  https://sacramentokoi.com/wp-content/uploads/2...
# 4  https://sacramentokoi.com/wp-content/uploads/2...
