# %% [markdown]
# # Bigger Dataset - EDA 3: NextDayKoi & SacramentoKoi

# %%
# imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# import data

nextdaykoi = pd.read_csv('../data/nextdaykoi_data.csv')
sacramentokoi = pd.read_csv('../data/sacramentokoi_data.csv')

# %% [markdown]
# # Data from NextDayKoi - 1948 pictures

# %%
# check the info

nextdaykoi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1948 entries, 0 to 1947
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1948 non-null   object
#  1   link        1948 non-null   object
#  2   title       1948 non-null   object
#  3   category    1948 non-null   object
#  4   price       1948 non-null   object
#  5   sku         1910 non-null   object
#  6   image       1948 non-null   object
#  7   image_url   1948 non-null   object
# dtypes: object(8)
# memory usage: 121.9+ KB

# %%
# check the data

nextdaykoi.head()
# Out:
#   Unnamed: 0                                               link  \
# 0   02f31ccb  https://nextdaykoi.com/product/3-5-imported-sh...
# 1   bec4495e  https://nextdaykoi.com/product/3-5-imported-ko...
# 2   62543bb1  https://nextdaykoi.com/product/3-5-imported-ar...
# 3   ea7ff9e9  https://nextdaykoi.com/product/3-5-imported-be...
# 4   f6ec77bc  https://nextdaykoi.com/product/3-5-imported-gi...
#
#                                  title  \
# 0                 3.5” Imported Shusui
# 1                 3.5” Imported Kohaku
# 2  3.5” Imported Armor Scaled Hariwake
# 3       3.5” Imported Doitsu Aka Bekko
# 4       3.5” Imported Gin Rin Hariwake
#
#                                             category   price              sku  \
# 0  ['Asagi and Shusui', 'Imported Koi', 'Koi', 'S...  $30.00  HS0505G01515C14
# 1  ['Gosanke', 'Imported Koi', 'Kohaku', 'Koi', '...  $30.00  HS0505G01515C13
# 2  ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', '...  $30.00  HS0505G01515C11
# 3  ['Aka Bekko', 'Bekko', 'Imported Koi', 'Koi', ...  $30.00  HS0505G01515C10
# 4  ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', '...  $30.00  HS0505G01515C08
#
#                                                image  \
# 0  nextdaykoi_data/02f31ccb_3.5”_Imported_Shusui.jpg
# 1  nextdaykoi_data/bec4495e_3.5”_Imported_Kohaku.jpg
# 2  nextdaykoi_data/62543bb1_3.5”_Imported_Armor_S...
# 3  nextdaykoi_data/ea7ff9e9_3.5”_Imported_Doitsu_...
# 4  nextdaykoi_data/f6ec77bc_3.5”_Imported_Gin_Rin...
#
#                                            image_url
# 0  https://d2e07cbkdk0gwy.cloudfront.net/wp-conte...
# 1  https://d2e07cbkdk0gwy.cloudfront.net/wp-conte...
# 2  https://d2e07cbkdk0gwy.cloudfront.net/wp-conte...
# 3  https://d2e07cbkdk0gwy.cloudfront.net/wp-conte...
# 4  https://d2e07cbkdk0gwy.cloudfront.net/wp-conte...

# %%
# check the titles vs the categories

for index, row in nextdaykoi.head(30).iterrows():
  print(index)
  print(row['title'])
  print(row['category'])
# Out:
# 0
# 3.5” Imported Shusui
# ['Asagi and Shusui', 'Imported Koi', 'Koi', 'Shusui', 'Single Fish', 'Single Koi']
# 1
# 3.5” Imported Kohaku
# ['Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# 2
# 3.5” Imported Armor Scaled Hariwake
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# 3
# 3.5” Imported Doitsu Aka Bekko
# ['Aka Bekko', 'Bekko', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# 4
# 3.5” Imported Gin Rin Hariwake
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# 5
# 3” Imported Gin Rin Hariwake
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# 6
# 3” Imported Doitsu Gin Shiro Bekko
# ['Bekko', 'Imported Koi', 'Koi', 'Shiro Bekko', 'Single Fish', 'Single Koi']
# 7
# 3” Imported Kikusui
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# 8
# 3” Imported Gin Rin Kujaku
# ['Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# 9
# Lot of (5) 2.5-3” Imported Assorted Oranda
# ['EFP Goldfish Lots', 'Goldfish For Sale', 'Imported Goldfish', 'Oranda']
# 10
# Lot of (5) 2.5-3” Imported Assorted Oranda
# ['EFP Goldfish Lots', 'Goldfish For Sale', 'Imported Goldfish', 'Oranda']
# 11
# Lot of (4) 2.5-3” Imported Assorted Oranda
# ['EFP Goldfish Lots', 'Goldfish For Sale', 'Imported Goldfish', 'Oranda']
# 12
# Lot of (4) 2.5-3” Imported Assorted Oranda
# ['EFP Goldfish Lots', 'Goldfish For Sale', 'Imported Goldfish', 'Oranda']
# 13
# Lot of (3) 2.5-3” Imported Assorted Oranda
# ['EFP Goldfish Lots', 'Goldfish For Sale', 'Imported Goldfish', 'Oranda']
# 14
# Lot of (3) 2.5-3” Imported Assorted Oranda
# ['EFP Goldfish Lots', 'Goldfish For Sale', 'Imported Goldfish', 'Oranda']
# 15
# 5” Imported Red and White Telescope Fantail
# ['Fantail', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# 16
# 4” Imported Calico Telescope Fantail
# ["Crystal's Featured Fish", 'Fantail', 'Featured Goldfish', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# 17
# 4” Imported Red and White Bubble Eye
# ['Bubble Eye', "Crystal's Featured Fish", 'Featured Goldfish', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# 18
# 4” Imported Male Red Bubble Eye
# ['Bubble Eye', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# 19
# 4” Imported Calico Telescope Fantail
# ['Fantail', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# 20
# 4” Imported Male Calico Ryukin
# ["Crystal's Featured Fish", 'Featured Goldfish', 'Goldfish For Sale', 'Imported Goldfish', 'Ryukin', 'Single Fish', 'Single Goldfish']
# 21
# 4” Imported Male Calico Ryukin
# ['Goldfish For Sale', 'Imported Goldfish', 'Ryukin', 'Single Fish', 'Single Goldfish']
# 22
# 4” Imported Male Calico Fantail
# ["Crystal's Featured Fish", 'Fantail', 'Featured Goldfish', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# 23
# 4” Imported Male Calico Ryukin
# ['Goldfish For Sale', 'Imported Goldfish', 'Ryukin', 'Single Fish', 'Single Goldfish']
# 24
# 3.5” Imported Calico Telescope Fantail
# ['Fantail', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# 25
# 3.5” Imported Calico Ryukin
# ["Crystal's Featured Fish", 'Featured Goldfish', 'Goldfish For Sale', 'Imported Goldfish', 'Ryukin', 'Single Fish', 'Single Goldfish']
# 26
# 3.5” Imported Calico Telescope Fantail
# ['Fantail', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# 27
# 7” Imported Gin Matsuba Butterfly Koi
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# 28
# 7” Imported Hariwake Butterfly Koi
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# 29
# 8” Imported Yamato Nishiki Butterfly Koi
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']

# %% [markdown]
# - get the length_inches from the title
# - get the gender from the title, if present
# - the title has information that is not in the category, so get all words other than 'Imported' and 'Koi'

# %%
# create a function to check if the first word is a number, if so, return it in new feature length_inches

def get_length(string):
  if string.split()[0][0].isdigit():
    return string.split()[0]

# %%
# apply the function to the whole dataset

nextdaykoi['length_inches'] = nextdaykoi['title'].apply(get_length)
nextdaykoi['length_inches']
# Out:
# 0       3.5”
# 1       3.5”
# 2       3.5”
# 3       3.5”
# 4       3.5”
#         ...
# 1943    5-6”
# 1944    None
# 1945    5-6”
# 1946    2-3″
# 1947    2-3″
# Name: length_inches, Length: 1948, dtype: object

# %%
# check how many are nulls

nextdaykoi['length_inches'].isna().sum()
# Out:
# np.int64(45)

# %%
# extract the gender if present

for word in nextdaykoi['title'][20].split():
  if word.lower() in ['male', 'female']:
    print(word)
# Out:
# Male

# %%
# create a function to extract the gender into a new column

def get_gender(string):
  for word in string.split():
    if word.lower() in ['male', 'female']:
      return word

# %%
# apply the function to the dataset

nextdaykoi['gender'] = nextdaykoi['title'].apply(get_gender)
nextdaykoi['gender']
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 1943    None
# 1944    None
# 1945    None
# 1946    None
# 1947    None
# Name: gender, Length: 1948, dtype: object

# %%
# check value_counts

nextdaykoi['gender'].value_counts()
# Out:
# gender
# Male      133
# Female     16
# Name: count, dtype: int64

# %% [markdown]
# - there is not much data, this feature may need to be dropped later

# %%
nextdaykoi['title'][100]
# Out:
# '4.5” Imported Doitsu Blue Kujaku'

# %%
# extract other words as tags (words that are not gender-related, "imported", "lot", "of" or "koi" and starts with a alphabet letter)

words_to_ignore = ['imported', 'lot', 'of', 'koi', 'assorted', 'and']

tags_list = []
for word in nextdaykoi['title'][100].split():
  if word.lower() not in words_to_ignore and word[0].isalpha():
    tags_list.append(word)

tags_list
# Out:
# ['Doitsu', 'Blue', 'Kujaku']

# %%
# create a function to extract the tags

def get_tags_from_title(string):
  words_to_ignore = ['imported', 'lot', 'of', 'koi', 'assorted', 'and']
  tags_list = []
  for word in string.split():
    if word.lower() not in words_to_ignore and word[0].isalpha():
      tags_list.append(word)
  return tags_list

# %%
# apply the function to the dataset

nextdaykoi['tags_from_title'] = nextdaykoi['title'].apply(get_tags_from_title)
nextdaykoi['tags_from_title']
# Out:
# 0                         [Shusui]
# 1                         [Kohaku]
# 2        [Armor, Scaled, Hariwake]
# 3             [Doitsu, Aka, Bekko]
# 4             [Gin, Rin, Hariwake]
#                    ...
# 1943               [Goldfish, Mix]
# 1944           [AA, Grade, Grade)]
# 1945    [Apricot, Comet, Goldfish]
# 1946     [Mixed, Oranda, Goldfish]
# 1947    [Mixed, Fantail, Goldfish]
# Name: tags_from_title, Length: 1948, dtype: object

# %%
# join the category feature with the tags_from_title to create the final tags feature
# check the type of the data

type(nextdaykoi['category'][0])
# Out:
# str

# %%
# the category is a string that is a list of strings, turn it back into a list of strings

nextdaykoi['category'][0]
# Out:
# "['Asagi and Shusui', 'Imported Koi', 'Koi', 'Shusui', 'Single Fish', 'Single Koi']"

# %%
# the category is a string that is a list of strings, turn it back into a list of strings
# strip the double quotes

print(nextdaykoi['category'][0].strip('"'))
# Out:
# ['Asagi and Shusui', 'Imported Koi', 'Koi', 'Shusui', 'Single Fish', 'Single Koi']

# %%
# strip the brackets

print(nextdaykoi['category'][0].strip('"').strip('[]'))
# Out:
# 'Asagi and Shusui', 'Imported Koi', 'Koi', 'Shusui', 'Single Fish', 'Single Koi'

# %%
# split by ", "

print(nextdaykoi['category'][0].strip('"').strip('[]').split(", "))
# Out:
# ["'Asagi and Shusui'", "'Imported Koi'", "'Koi'", "'Shusui'", "'Single Fish'", "'Single Koi'"]

# %%
# strip the single quotes

print([item.strip("'") for item in nextdaykoi['category'][0].strip('"').strip('[]').split(", ")])
# Out:
# ['Asagi and Shusui', 'Imported Koi', 'Koi', 'Shusui', 'Single Fish', 'Single Koi']

# %%
# create a function to turn the string of list of strings into a list of strings

def string_to_list(string):
  return [item.strip("'") for item in string.strip('"').strip('[]').split(", ")]

# %%
# apply the function to the dataset

nextdaykoi['tags_from_category'] = nextdaykoi['category'].apply(string_to_list)
nextdaykoi['tags_from_category']
# Out:
# 0       [Asagi and Shusui, Imported Koi, Koi, Shusui, ...
# 1       [Gosanke, Imported Koi, Kohaku, Koi, Single Fi...
# 2       [All Hikari Koi, Hariwake, Hikarimoyo, Importe...
# 3       [Aka Bekko, Bekko, Imported Koi, Koi, Single F...
# 4       [All Hikari Koi, Hariwake, Hikarimoyo, Importe...
#                               ...
# 1943    [Goldfish Pond Packs, Pond Pack Koi, Butterfly...
# 1944    [Koi Pond Packs, Pond Pack Koi, Butterfly Koi ...
# 1945    [Goldfish Pond Packs, Pond Pack Koi, Butterfly...
# 1946    [Goldfish Pond Packs, Pond Pack Koi, Butterfly...
# 1947    [Goldfish Pond Packs, Pond Pack Koi, Butterfly...
# Name: tags_from_category, Length: 1948, dtype: object

# %%
# double check the type

type(nextdaykoi['tags_from_category'][0])
# Out:
# list

# %%
# combine the two lists of tags into a final tags column

nextdaykoi['tags'] = nextdaykoi['tags_from_title'] = nextdaykoi['tags_from_category']
nextdaykoi['tags']
# Out:
# 0       [Asagi and Shusui, Imported Koi, Koi, Shusui, ...
# 1       [Gosanke, Imported Koi, Kohaku, Koi, Single Fi...
# 2       [All Hikari Koi, Hariwake, Hikarimoyo, Importe...
# 3       [Aka Bekko, Bekko, Imported Koi, Koi, Single F...
# 4       [All Hikari Koi, Hariwake, Hikarimoyo, Importe...
#                               ...
# 1943    [Goldfish Pond Packs, Pond Pack Koi, Butterfly...
# 1944    [Koi Pond Packs, Pond Pack Koi, Butterfly Koi ...
# 1945    [Goldfish Pond Packs, Pond Pack Koi, Butterfly...
# 1946    [Goldfish Pond Packs, Pond Pack Koi, Butterfly...
# 1947    [Goldfish Pond Packs, Pond Pack Koi, Butterfly...
# Name: tags, Length: 1948, dtype: object

# %%
for _, row in nextdaykoi.iterrows():
  print(row['tags'])
# Out:
# ['Asagi and Shusui', 'Imported Koi', 'Koi', 'Shusui', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Aka Bekko', 'Bekko', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Bekko', 'Imported Koi', 'Koi', 'Shiro Bekko', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['EFP Goldfish Lots', 'Goldfish For Sale', 'Imported Goldfish', 'Oranda']
# ['EFP Goldfish Lots', 'Goldfish For Sale', 'Imported Goldfish', 'Oranda']
# ['EFP Goldfish Lots', 'Goldfish For Sale', 'Imported Goldfish', 'Oranda']
# ['EFP Goldfish Lots', 'Goldfish For Sale', 'Imported Goldfish', 'Oranda']
# ['EFP Goldfish Lots', 'Goldfish For Sale', 'Imported Goldfish', 'Oranda']
# ['EFP Goldfish Lots', 'Goldfish For Sale', 'Imported Goldfish', 'Oranda']
# ['Fantail', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# ['"Crystal\'s Featured Fish"', 'Fantail', 'Featured Goldfish', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# ['Bubble Eye', '"Crystal\'s Featured Fish"', 'Featured Goldfish', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# ['Bubble Eye', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# ['Fantail', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# ['"Crystal\'s Featured Fish"', 'Featured Goldfish', 'Goldfish For Sale', 'Imported Goldfish', 'Ryukin', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Ryukin', 'Single Fish', 'Single Goldfish']
# ['"Crystal\'s Featured Fish"', 'Fantail', 'Featured Goldfish', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Ryukin', 'Single Fish', 'Single Goldfish']
# ['Fantail', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# ['"Crystal\'s Featured Fish"', 'Featured Goldfish', 'Goldfish For Sale', 'Imported Goldfish', 'Ryukin', 'Single Fish', 'Single Goldfish']
# ['Fantail', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Kikokuryu', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['All Hikari Koi', 'Butterfly Koi', 'Heisei Nishik', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamabuki']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Imported Koi', 'Kawarimono', 'Koi', 'Single Fish', 'Single Koi', 'Soragoi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kin Kikokuryu', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Platinum Ogon', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Chagoi', 'Imported Koi', 'Kawarimono', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['"Crystal\'s Featured Fish"', 'Imported Koi', 'Kawarimono', 'Koi', 'Single Fish', 'Single Koi', 'Soragoi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Koi', 'Showa', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['Asagi and Shusui', 'Imported Koi', 'Koi', 'Shusui', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Platinum Ogon', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamabuk']
# ['All Hikari Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Platinum Ogon', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimuji', 'Imported Koi', 'Koi', 'Platinum Ogon', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Heisei Nishik', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Platinum Ogon', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamabuki']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', '"Crystal\'s Featured Fish"', 'Imported Koi', 'Kawarimono', 'Koi', 'Ochiba Shigure', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Kin Kikokuryu', 'Koi', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['All Hikari Koi', '"Crystal\'s Featured Fish"', 'Heisei Nishiki', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Chagoi', 'Imported Koi', 'Kawarimono', 'Koi', 'Single Fish', 'Single Koi']
# ['"Crystal\'s Featured Fish"', 'Goshiki', 'Imported Koi', 'Koi', 'Koromo', 'Single Fish', 'Single Koi']
# ['Hi Utsuri', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Utsurimono']
# ['Imported Koi', 'Kawarimono', 'Koi', 'Kumonryu', 'Single Fish', 'Single Koi']
# ['"Crystal\'s Featured Fish"', 'Imported Koi', 'Ki Utsuri', 'Koi', 'Single Fish', 'Single Koi', 'Utsurimono']
# ['Butterfly Koi', 'Chagoi', 'Imported Koi', 'Kawarimono', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Heisei Nishiki', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kin Kikokuryu', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kin Kikokuryu', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Heisei Nishiki', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Bekko', 'Imported Koi', 'Koi', 'Shiro Bekko', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['Goromo', 'Imported Koi', 'Koi', 'Koromo', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['Asagi and Shusui', 'Imported Koi', 'Koi', 'Shusui', 'Single Fish', 'Single Koi']
# ['Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Chagoi', 'Imported Koi', 'Kawarimono', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamabuki']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Orenji Ogon', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kin Kikokuryu', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Orenji Ogon', 'Single Fish', 'Single Koi']
# ['Aka Bekko', 'Bekko', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['Asagi', 'Asagi and Shusui', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Imported Koi', 'Kawarimono', 'Koi', 'Single Fish', 'Single Koi', 'Soragoi']
# ['Imported Koi', 'Kawarimono', 'Koi', 'Ochiba Shigure', 'Single Fish', 'Single Koi']
# ['Asagi and Shusui', 'Imported Koi', 'Koi', 'Shusui', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Kikokuryu', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', '"Crystal\'s Featured Fish"', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Asagi and Shusui', '"Crystal\'s Featured Fish"', 'Imported Koi', 'Koi', 'Shusui', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Platinum Ogon', 'Single Fish', 'Single Koi']
# ['Bekko', 'Imported Koi', 'Koi', 'Shiro Bekko', 'Single Fish', 'Single Koi']
# ['Asagi', 'Asagi and Shusui', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Asagi and Shusui', 'Imported Koi', 'Koi', 'Shusui', 'Single Fish', 'Single Koi']
# ['Imported Koi', 'Kawarimono', 'Koi', 'Single Fish', 'Single Koi', 'Soragoi']
# ['Bekko', 'Imported Koi', 'Koi', 'Shiro Bekko', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['Hi Utsuri', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Utsurimono']
# ['Asagi', 'Asagi and Shusui', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Bekko', 'Imported Koi', 'Ki Bekko', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['Butterfly Koi', 'Gold Crown', 'Imported Koi', 'Kawarimono', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kikokuryu', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimuji', 'Imported Koi', 'Koi', 'Platinum Ogon', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['Aka Bekko', 'Bekko', 'Butterfly Koi', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['All Hikari Koi', 'Butterfly Koi', 'Heisei Nishik', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Aka Bekko', 'Bekko', 'Butterfly Koi', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['Aka Bekko', 'Bekko', 'Butterfly Koi', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Hi Utsuri', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Utsurimono']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamabuki']
# ['Butterfly Koi', 'Chagoi', '"Crystal\'s Featured Fish"', 'Imported Koi', 'Kawarimono', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Orenji Ogon', 'Single Fish', 'Single Koi']
# ['Bekko', 'Butterfly Koi', 'Imported Koi', 'Koi', 'Shiro Bekko', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Platinum Ogon', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kin Kikokuryu', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['Butterfly Koi', 'Imported Koi', 'Kawarimono', 'Koi', 'Ochiba Shigure', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimuji', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamabuki']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kin Kikokuryu', 'Koi', 'Single Fish', 'Single Koi']
# ['Bekko', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Imported Koi', 'Koi', 'Shiro Bekko', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Hi Utsuri', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Utsurimono']
# ['Asagi and Shusui', 'Butterfly Koi', 'Imported Koi', 'Koi', 'Shusui', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Goldfish For Sale', 'Imported Goldfish', 'Ryukin', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Ryukin', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Ryukin', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Ryukin', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Ryukin', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Ryukin', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Ryukin', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Ryukin', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Ryukin', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Ryukin', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Ryukin', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['"Crystal\'s Featured Fish"', 'Featured Goldfish', 'Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Imported Koi', 'Kawarimono', 'Koi', 'Ochiba Shigure', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamabuk']
# ['Asagi and Shusui', '"Crystal\'s Featured Fish"', 'Imported Koi', 'Koi', 'Shusui', 'Single Fish', 'Single Koi']
# ['Chagoi', '"Crystal\'s Featured Fish"', 'Imported Koi', 'Kawarimono', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['All Hikari Koi', '"Crystal\'s Featured Fish"', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['Imported Koi', 'Koi', 'Shiro Utsuri', 'Single Fish', 'Single Koi', 'Utsurimono']
# ['Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['Hi Utsuri', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Utsurimono']
# ['Butterfly Koi', '"Crystal\'s Featured Fish"', 'Imported Koi', 'Kawarimono', 'Koi', 'Ochiba Shigure', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamabuki']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Platinum Ogon', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Heisei Nishiki', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', '"Crystal\'s Featured Fish"', 'Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Chagoi', 'Imported Koi', 'Kawarimono', 'Koi', 'Single Fish', 'Single Koi']
# ['EFP Koi Lots', 'Imported Koi', 'Koi']
# ['EFP Koi Lots', 'Imported Koi', 'Koi']
# ['EFP Koi Lots', 'Imported Koi', 'Koi']
# ['EFP Koi Lots', 'Imported Koi', 'Koi']
# ['EFP Koi Lots', 'Imported Koi', 'Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamabuki']
# ['Butterfly Koi', 'Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kin Kikokuryu', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', '"Crystal\'s Featured Fish"', 'Imported Koi', 'Kawarimono', 'Koi', 'Ochiba Shigure', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Heisei Nishik', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Hi Utsuri', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Utsurimono']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamabuki']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kin Kikokuryu', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['Hi Utsuri', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Utsurimono']
# ['All Hikari Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamabuk']
# ['All Hikari Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Orenji Ogon', 'Single Fish', 'Single Koi']
# ['Chagoi', 'Imported Koi', 'Kawarimono', 'Koi', 'Single Fish', 'Single Koi']
# ['"Crystal\'s Featured Fish"', 'Imported Koi', 'Kawarimono', 'Koi', 'Single Fish', 'Single Koi', 'Soragoi']
# ['Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Heisei Nishiki', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['Imported Koi', 'Kawarimono', 'Koi', 'Ochiba Shigure', 'Single Fish', 'Single Koi']
# ['"Crystal\'s Featured Fish"', 'Goromo', 'Imported Koi', 'Koi', 'Koromo', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['Imported Koi', 'Koi', 'Shiro Utsuri', 'Single Fish', 'Single Koi', 'Utsurimono']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Platinum Ogon', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Orenji Ogon', 'Single Fish', 'Single Koi']
# ['"Crystal\'s Featured Fish"', 'Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Heisei Nishiki', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', '"Crystal\'s Featured Fish"', 'Hikarimuji', 'Imported Koi', 'Koi', 'Platinum Ogon', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', '"Crystal\'s Featured Fish"', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Goromo', 'Imported Koi', 'Koi', 'Koromo', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['Hajiro', 'Imported Koi', 'Kawarimono', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Bekko', 'Imported Koi', 'Koi', 'Shiro Bekko', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['Asagi', 'Asagi and Shusui', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Aka Bekko', 'Bekko', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Orenji Ogon', 'Single Fish', 'Single Koi']
# ['Asagi and Shusui', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Imported Koi', 'Koi', 'Shusui', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', '"Crystal\'s Featured Fish"', 'Imported Koi', 'Ki Utsuri', 'Koi', 'Single Fish', 'Single Koi', 'Utsurimono']
# ['Butterfly Koi', 'Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['All Hikari Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['Aka Bekko', 'Bekko', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Bekko', 'Imported Koi', 'Koi', 'Shiro Bekko', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['Asagi and Shusui', 'Imported Koi', 'Koi', 'Shusui', 'Single Fish', 'Single Koi']
# ['Asagi', 'Asagi and Shusui', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Bekko', 'Imported Koi', 'Ki Bekko', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Bekko', 'Imported Koi', 'Koi', 'Shiro Bekko', 'Single Fish', 'Single Koi']
# ['Bekko', 'Imported Koi', 'Ki Bekko', 'Koi', 'Single Fish', 'Single Koi']
# ['Bekko', 'Butterfly Koi', 'Imported Koi', 'Koi', 'Shiro Bekko', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Imported Koi', 'Koi', 'Shiro Utsuri', 'Single Fish', 'Single Koi', 'Utsurimono']
# ['All Hikari Koi', 'Butterfly Koi', 'Heisei Nishiki', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Imported Koi', 'Kawarimono', 'Koi', 'Single Fish', 'Single Koi', 'Soragoi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimuji', 'Imported Koi', 'Koi', 'Platinum Ogon', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Kin Kikokuryu', 'Koi', 'Single Fish', 'Single Koi']
# ['Goromo', 'Imported Koi', 'Koi', 'Koromo', 'Single Fish', 'Single Koi']
# ['Imported Koi', 'Kawarimono', 'Koi', 'Single Fish', 'Single Koi', 'Soragoi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Kin Kikokuryu', 'Koi', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Kin Kikokuryu', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['Imported Koi', 'Kawarimono', 'Koi', 'Single Fish', 'Single Koi', 'Soragoi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', '"Crystal\'s Featured Fish"', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamabuki']
# ['Butterfly Koi', 'Imported Koi', 'Kawarimono', 'Koi', 'Ochiba Shigure', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Hi Utsuri', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Utsurimono']
# ['All Hikari Koi', 'Butterfly Koi', 'Heisei Nishik', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Aka Bekko', 'Bekko', 'Butterfly Koi', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Heisei Nishiki', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Orenji Ogon', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['Fantail', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# ['Butterfly Tail', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Butterfly Koi Pond Packs', 'New Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', '"Crystal\'s Featured Fish"', 'Imported Koi', 'Kawarimono', 'Koi', 'Ochiba Shigure', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['Asagi and Shusui', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Imported Koi', 'Koi', 'Shusui', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Chagoi', 'Imported Koi', 'Kawarimono', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Platinum Ogon', 'Single Fish', 'Single Koi']
# ['Asagi and Shusui', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Imported Koi', 'Koi', 'Shusui', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Kin Kikokuryu', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamabuki']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Heisei Nishik', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', '"Crystal\'s Featured Fish"', 'Gosanke', 'Imported Koi', 'Koi', 'Other Tancho', 'Sanke', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish', 'Wakin']
# ['Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish', 'Wakin']
# ['Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish', 'Wakin']
# ['Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish', 'Wakin']
# ['Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish', 'Wakin']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['"Crystal\'s Featured Fish"', 'Featured Goldfish', 'Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', '"Crystal\'s Featured Fish"', 'Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Imported Koi', 'Ki Utsuri', 'Koi', 'Single Fish', 'Single Koi', 'Utsurimono']
# ['All Hikari Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Orenji Ogon', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['All Hikari Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Platinum Ogon', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', '"Crystal\'s Featured Fish"', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Matsuba', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['Imported Koi', 'Koi', 'Shiro Utsuri', 'Single Fish', 'Single Koi', 'Utsurimono']
# ...
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamabuki']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Kin Kikokuryu', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['Hi Utsuri', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Utsurimono']
# ['Butterfly Koi', 'Imported Koi', 'Kawarimono', 'Koi', 'Ochiba Shigure', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Platinum Ogon', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', '"Crystal\'s Featured Fish"', 'Heisei Nishiki', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['4-5" Koi & Butterfly Koi', 'Butterfly Koi', 'Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['4-5" Koi & Butterfly Koi', 'All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['4-5" Koi & Butterfly Koi', 'All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['4-5" Koi & Butterfly Koi', 'All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['4-5" Koi & Butterfly Koi', 'All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['4-5" Koi & Butterfly Koi', '"Crystal\'s Featured Fish"', 'Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['4-5" Koi & Butterfly Koi', 'All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kin Kikokuryu', 'Koi', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['Goldfish For Sale', 'Imported Goldfish', 'Ranchu', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Ryukin', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Ranchu', 'Single Fish', 'Single Goldfish']
# ['Butterfly Tail', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Pearlscale', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Pearlscale', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Pearlscale', 'Single Fish', 'Single Goldfish']
# ['"Crystal\'s Featured Fish"', 'Featured Goldfish', 'Goldfish For Sale', 'Imported Goldfish', 'Pearlscale', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Pearlscale', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Pearlscale', 'Single Fish', 'Single Goldfish']
# ['"Crystal\'s Featured Fish"', 'Featured Goldfish', 'Goldfish For Sale', 'Imported Goldfish', 'Pearlscale', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Pearlscale', 'Single Fish', 'Single Goldfish']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Kin Kikokuryu', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kin Kikokuryu', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kin Kikokuryu', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Heisei Nishiki', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Orenji Ogon', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Heisei Nishiki', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['Asagi and Shusui', 'Imported Koi', 'Koi', 'Shusui', 'Single Fish', 'Single Koi']
# ['Imported Koi', 'Kawarimono', 'Koi', 'Kumonryu', 'Single Fish', 'Single Koi']
# ['Bekko', 'Imported Koi', 'Koi', 'Shiro Bekko', 'Single Fish', 'Single Koi']
# ['Butterfly Tail', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# ['4-5" Koi & Butterfly Koi', 'All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Imported Koi', 'Kawarimono', 'Koi', 'Ochiba Shigure', 'Single Fish', 'Single Koi']
# ['Aka Bekko', 'Bekko', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', '"Crystal\'s Featured Fish"', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['4-5" Koi & Butterfly Koi', 'All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['4-5" Koi & Butterfly Koi', 'All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['4-5" Koi & Butterfly Koi', 'Imported Koi', 'Kawarimono', 'Koi', 'Ochiba Shigure', 'Single Fish', 'Single Koi']
# ['4-5" Koi & Butterfly Koi', 'All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kin Kikokuryu', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Heisei Nishiki', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Heisei Nishiki', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['All Hikari Koi', 'Butterfly Koi', 'Heisei Nishiki', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kin Kikokuryu', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamabuki']
# ['Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['Gosanke', 'Imported Koi', 'Koi', 'Sanke', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Heisei Nishiki', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['Fantail', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# ['Fantail', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# ['"Crystal\'s Featured Fish"', 'Fantail', 'Featured Goldfish', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# ['Fantail', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# ['Fantail', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# ['4-5" Koi & Butterfly Koi', 'All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['Butterfly Koi', 'Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['Goldfish For Sale', 'Imported Goldfish', 'Ranchu', 'Single Fish', 'Single Goldfish']
# ['Imported Koi', 'Kawarimono', 'Koi', 'Ochiba Shigure', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Butterfly Tail', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# ['Butterfly Tail', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# ['EFP Goldfish Lots', 'Goldfish For Sale', 'Imported Goldfish', 'Shubunkin']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kin Kikokuryu', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi', 'Yamato Nishiki']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['Butterfly Koi', 'Imported Koi', 'Kawarimono', 'Koi', 'Single Fish', 'Single Koi', 'Soragoi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimuji', 'Imported Koi', 'Koi', 'Orenji Ogon', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Butterfly Koi', 'Hikarimoyo', 'Imported Koi', 'Kikusui', 'Koi', 'Single Fish', 'Single Koi']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Oranda', 'Single Fish', 'Single Goldfish']
# ['Bubble Eye', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# ['Bubble Eye', '"Crystal\'s Featured Fish"', 'Featured Goldfish', 'Goldfish For Sale', 'Imported Goldfish', 'Single Fish', 'Single Goldfish']
# ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['4-5" Koi & Butterfly Koi', 'Goromo', 'Imported Koi', 'Koi', 'Koromo', 'Single Fish', 'Single Koi']
# ['4-5" Koi & Butterfly Koi', 'Gosanke', 'Imported Koi', 'Kohaku', 'Koi', 'Single Fish', 'Single Koi']
# ['4-5" Koi & Butterfly Koi', 'All Hikari Koi', 'Hariwake', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Single Fish', 'Single Koi']
# ['4-5" Koi & Butterfly Koi', 'All Hikari Koi', 'Hikarimoyo', 'Imported Koi', 'Koi', 'Kujaku', 'Single Fish', 'Single Koi']
# ['Goldfish For Sale', 'Imported Goldfish', 'Ranchu', 'Single Fish', 'Single Goldfish']
# ['Goldfish Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Shubunkin', 'Single Fish', 'Single Goldfish']
# ['Goldfish For Sale', 'Imported Goldfish', 'Sarasa Comet', 'Single Fish', 'Single Goldfish']
# ['Goldfish Pond Packs', 'New Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Goldfish Pond Packs', 'New Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Butterfly Koi Pond Packs', 'New Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Goldfish Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Goldfish Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Goldfish Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Butterfly Koi Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Goldfish Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Goldfish Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Goldfish Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Goldfish Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Koi Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Goldfish Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Goldfish Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Goldfish Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Butterfly Koi Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Goldfish Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Goldfish Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Goldfish Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Goldfish Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Koi Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Butterfly Koi Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Goldfish Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Koi Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Goldfish Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Goldfish Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']
# ['Goldfish Pond Packs', 'Pond Pack Koi', 'Butterfly Koi & Goldfish']

# %%
# rename 'Unnamed: 0' column to 'uuid

nextdaykoi = nextdaykoi.rename(columns={'Unnamed: 0': 'uuid'})
nextdaykoi.head()
# Out:
#        uuid                                               link  \
# 0  02f31ccb  https://nextdaykoi.com/product/3-5-imported-sh...
# 1  bec4495e  https://nextdaykoi.com/product/3-5-imported-ko...
# 2  62543bb1  https://nextdaykoi.com/product/3-5-imported-ar...
# 3  ea7ff9e9  https://nextdaykoi.com/product/3-5-imported-be...
# 4  f6ec77bc  https://nextdaykoi.com/product/3-5-imported-gi...
#
#                                  title  \
# 0                 3.5” Imported Shusui
# 1                 3.5” Imported Kohaku
# 2  3.5” Imported Armor Scaled Hariwake
# 3       3.5” Imported Doitsu Aka Bekko
# 4       3.5” Imported Gin Rin Hariwake
#
#                                             category   price              sku  \
# 0  ['Asagi and Shusui', 'Imported Koi', 'Koi', 'S...  $30.00  HS0505G01515C14
# 1  ['Gosanke', 'Imported Koi', 'Kohaku', 'Koi', '...  $30.00  HS0505G01515C13
# 2  ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', '...  $30.00  HS0505G01515C11
# 3  ['Aka Bekko', 'Bekko', 'Imported Koi', 'Koi', ...  $30.00  HS0505G01515C10
# 4  ['All Hikari Koi', 'Hariwake', 'Hikarimoyo', '...  $30.00  HS0505G01515C08
#
#                                                image  \
# 0  nextdaykoi_data/02f31ccb_3.5”_Imported_Shusui.jpg
# 1  nextdaykoi_data/bec4495e_3.5”_Imported_Kohaku.jpg
# 2  nextdaykoi_data/62543bb1_3.5”_Imported_Armor_S...
# 3  nextdaykoi_data/ea7ff9e9_3.5”_Imported_Doitsu_...
# 4  nextdaykoi_data/f6ec77bc_3.5”_Imported_Gin_Rin...
#
#                                            image_url length_inches gender  \
# 0  https://d2e07cbkdk0gwy.cloudfront.net/wp-conte...          3.5”   None
# 1  https://d2e07cbkdk0gwy.cloudfront.net/wp-conte...          3.5”   None
# 2  https://d2e07cbkdk0gwy.cloudfront.net/wp-conte...          3.5”   None
# 3  https://d2e07cbkdk0gwy.cloudfront.net/wp-conte...          3.5”   None
# 4  https://d2e07cbkdk0gwy.cloudfront.net/wp-conte...          3.5”   None
#
#                                      tags_from_title  \
# 0  [Asagi and Shusui, Imported Koi, Koi, Shusui, ...
# 1  [Gosanke, Imported Koi, Kohaku, Koi, Single Fi...
# 2  [All Hikari Koi, Hariwake, Hikarimoyo, Importe...
# 3  [Aka Bekko, Bekko, Imported Koi, Koi, Single F...
# 4  [All Hikari Koi, Hariwake, Hikarimoyo, Importe...
#
#                                   tags_from_category  \
# 0  [Asagi and Shusui, Imported Koi, Koi, Shusui, ...
# 1  [Gosanke, Imported Koi, Kohaku, Koi, Single Fi...
# 2  [All Hikari Koi, Hariwake, Hikarimoyo, Importe...
# 3  [Aka Bekko, Bekko, Imported Koi, Koi, Single F...
# 4  [All Hikari Koi, Hariwake, Hikarimoyo, Importe...
#
#                                                 tags
# 0  [Asagi and Shusui, Imported Koi, Koi, Shusui, ...
# 1  [Gosanke, Imported Koi, Kohaku, Koi, Single Fi...
# 2  [All Hikari Koi, Hariwake, Hikarimoyo, Importe...
# 3  [Aka Bekko, Bekko, Imported Koi, Koi, Single F...
# 4  [All Hikari Koi, Hariwake, Hikarimoyo, Importe...

# %%
# export the dataframe to csv

# nextdaykoi.to_csv('nextdaykoi_df.csv', index=False)

# %% [markdown]
# # Data from Sacramentokoi - 423 pictures

# %%
# check the info

sacramentokoi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    423 non-null    object
#  1   link          423 non-null    object
#  2   title         423 non-null    object
#  3   category      423 non-null    object
#  4   out_of_stock  423 non-null    bool
#  5   price         423 non-null    object
#  6   sku           422 non-null    float64
#  7   image         423 non-null    object
#  8   image_url     423 non-null    object
# dtypes: bool(1), float64(1), object(7)
# memory usage: 27.0+ KB

# %%
# check the data

sacramentokoi.head()
# Out:
#   Unnamed: 0                                               link  \
# 0     cd3cf5  https://sacramentokoi.com/ai-goromo-10-240054222/
# 1     617c1b  https://sacramentokoi.com/ai-goromo-20-240389171/
# 2     5027b5  https://sacramentokoi.com/ai-goromo-23-240396257/
# 3     ebda82  https://sacramentokoi.com/ai-goromo-24-231616208/
# 4     10edc1  https://sacramentokoi.com/aka-matsuba-11-24005...
#
#                          title category  out_of_stock      price          sku  \
# 0    Ai Goromo 10″ – 240054222   Goromo          True    $150.00  240054222.0
# 1    Ai Goromo 20″ – 240389171   Female          True  $1,200.00  240389171.0
# 2    Ai Goromo 23″ – 240396257   Female          True  $1,200.00  240396257.0
# 3    Ai Goromo 27″ – 231616208   Female          True  $4,200.00  231616208.0
# 4  Aka Matsuba 11″ – 240054184      Koi          True    $175.00  240054184.0
#
#                                                image  \
# 0  sacramentokoi_data/cd3cf5_Ai_Goromo_10″_–_2400...
# 1  sacramentokoi_data/617c1b_Ai_Goromo_20″_–_2403...
# 2  sacramentokoi_data/5027b5_Ai_Goromo_23″_–_2403...
# 3  sacramentokoi_data/ebda82_Ai_Goromo_27″_–_2316...
# 4  sacramentokoi_data/10edc1_Aka_Matsuba_11″_–_24...
#
#                                            image_url
# 0  https://sacramentokoi.com/wp-content/uploads/2...
# 1  https://sacramentokoi.com/wp-content/uploads/2...
# 2  https://sacramentokoi.com/wp-content/uploads/2...
# 3  https://sacramentokoi.com/wp-content/uploads/2...
# 4  https://sacramentokoi.com/wp-content/uploads/2...

# %%
# check the category types

sacramentokoi['category'].value_counts()
# Out:
# category
# Female              156
# Koi                  65
# Doitsu               45
# Gin Rin              44
# Asagi                21
# Aokiya               20
# Chagoi               11
# Benigoi              11
# Aragoke              10
# Goshiki               7
# Ikarashi Ozumi        6
# Kohaku                5
# Ginga                 4
# Kaneko                3
# Kikokuryu             3
# Ikarashi Toshi        2
# Kigoi                 2
# Fukasawa              2
# Karasu                1
# Goromo                1
# Gin Rin Metallic      1
# Doitsu Metallic       1
# Aragoke Metallic      1
# Bekko                 1
# Name: count, dtype: int64

# %% [markdown]
# - there is Female label but no Male label

# %%
# check more rows of the title

sacramentokoi['title']
# Out:
# 0          Ai Goromo 10″ – 240054222
# 1          Ai Goromo 20″ – 240389171
# 2          Ai Goromo 23″ – 240396257
# 3          Ai Goromo 27″ – 231616208
# 4        Aka Matsuba 11″ – 240054184
#                    ...
# 418    Yellow Dragon 17″ – 240154405
# 419     Yellow Ginga 14″ – 240054090
# 420     Yellow Ginga 19″ – 240489285
# 421     Yellow Ginga 20″ – 240290281
# 422                    Koi Pre-Order
# Name: title, Length: 423, dtype: object
